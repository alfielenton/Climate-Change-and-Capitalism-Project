# %% [markdown]
# <a href="https://colab.research.google.com/github/alfielenton/Climate-Change-and-Capitalism-Project/blob/main/Climate_Change_and_Capitalism_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install OpenPyXl

# %%
import pandas as pd
import openpyxl

from openpyxl import Workbook, load_workbook

# %%
CarbonBudget = load_workbook("GlobalCarbonBudget2022.xlsx")

# %%
SheetNames = ["Global Carbon Budget","Historical Budget","Fossil Emissions by Category","Land-Use Change Emissions","Ocean Sink","Terrestrial Sink","Cement Carbonation Sink"]
dfTotalXL = pd.read_excel("GlobalCarbonBudget2022.xlsx",sheet_name = SheetNames,header = None)

# %%
dfGCB = dfTotalXL[SheetNames[0]]
dfHB = dfTotalXL[SheetNames[1]]
dfFEbC = dfTotalXL[SheetNames[2]]
dfLCE = dfTotalXL[SheetNames[3]]
dfOS = dfTotalXL[SheetNames[4]]
dfTS = dfTotalXL[SheetNames[5]]
dfCCS = dfTotalXL[SheetNames[6]]

# %%
dfGCB.head()
# Out:
#      0                                                  1  \
# 0  NaN  All values in billion tonnes of carbon per yea...
# 1  NaN  Note: 1 billion tonnes C = 1 petagram of carbo...
# 2  NaN  All uncertainties represent ± 1 sigma error (6...
# 3  NaN  Emissions from fossil fuel combustion and indu...
# 4  NaN                                                NaN
#
#                                                    2    3    4    5    6    7
# 0                                                NaN  NaN  NaN  NaN  NaN  NaN
# 1                                                NaN  NaN  NaN  NaN  NaN  NaN
# 2                                                NaN  NaN  NaN  NaN  NaN  NaN
# 3                                                NaN  NaN  NaN  NaN  NaN  NaN
# 4  Cite as: Friedlingstein et al. 2022b (see Summ...  NaN  NaN  NaN  NaN  NaN

# %%
dfGCB.drop(dfGCB.index[0:20],inplace = True)

# %%
new_headers = dfGCB.iloc[0]
dfGCB = dfGCB[1:]
dfGCB.columns = new_headers

# %%
dfGCB.reset_index(drop = True,inplace = True)

# %%
dfGCB
# Out:
# 0   Year fossil emissions excluding carbonation land-use change emissions  \
# 1   1959                               2.417091                  1.938933
# 2   1960                               2.562137                    1.7926
# 3   1961                                2.57054                    1.6665
# 4   1962                               2.661315                  1.608267
# 5   1963                               2.803399                  1.542733
# ..   ...                                    ...                       ...
# 59  2017                                9.85173                    1.1823
# 60  2018                              10.050902                    1.1412
# 61  2019                              10.120786                    1.2438
# 62  2020                               9.624478                  1.107467
# 63  2021                              10.132055                  1.075067
#
# 0  atmospheric growth ocean sink land sink cement carbonation sink  \
# ...

# %%
dfGCB.to_excel("GlobalCarbonBudgetSheet.xlsx")
